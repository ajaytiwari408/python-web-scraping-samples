# %% [markdown]
# <a href="https://colab.research.google.com/github/ajaytiwari408/python-web-scraping-samples/blob/main/directory_scraper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import csv

url = "https://webscraper.io/test-sites/e-commerce/static"
response = requests.get(url)

soup = BeautifulSoup(response.text, "html.parser")

items = soup.find_all("a", class_="title")

data = []

for item in items:
    name = item.text.strip()
    link = item["href"]
    data.append([name, link])

with open("directory_output.csv", "w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow(["Name", "Link"])
    writer.writerows(data)

print(f"Saved {len(data)} items to CSV!")
# Out:
# Saved 3 items to CSV!
