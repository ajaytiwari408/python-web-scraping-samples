# %% [markdown]
# <a href="https://colab.research.google.com/github/ajaytiwari408/python-web-scraping-samples/blob/main/job_listings_scraper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import csv

url = "https://realpython.github.io/fake-jobs/"
response = requests.get(url)

soup = BeautifulSoup(response.text, "html.parser")

jobs = soup.find_all("div", class_="card-content")

data = []

for job in jobs:
    title = job.find("h2").text.strip()
    company = job.find("h3").text.strip()
    link = job.find("a")["href"]
    data.append([title, company, link])

with open("jobs_output.csv", "w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow(["Job Title", "Company", "Link"])
    writer.writerows(data)

print(f"Saved {len(data)} jobs to CSV!")
# Out:
# Saved 100 jobs to CSV!
