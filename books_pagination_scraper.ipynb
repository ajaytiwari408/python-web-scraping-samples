# %% [markdown]
# <a href="https://colab.research.google.com/github/ajaytiwari408/python-web-scraping-samples/blob/main/books_pagination_scraper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import csv

base_url = "https://books.toscrape.com/catalogue/page-{}.html"

all_books = []

for page in range(1, 4):  # first 3 pages
    url = base_url.format(page)
    response = requests.get(url)
    soup = BeautifulSoup(response.text, "html.parser")

    books = soup.find_all("h3")

    for book in books:
        title = book.find("a")["title"]
        link = book.find("a")["href"]
        all_books.append([title, link])

with open("books_multi_page.csv", "w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow(["Title", "Link"])
    writer.writerows(all_books)

print(f"Saved {len(all_books)} books to CSV!")
# Out:
# Saved 60 books to CSV!
